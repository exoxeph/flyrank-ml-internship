# %% [markdown]
# <a href="https://colab.research.google.com/github/exoxeph/flyrank-ml-internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/exoxeph/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# Lane 2 — Refresh / Content Opportunity Scoring
#
# I chose this lane because I want to build a model that helps prioritize which content pages should be reviewed first instead of treating every declining page equally. My main question is: Can observable search, content, and engagement signals rank pages by refresh opportunity better than a simple hand-written baseline? I like this lane because it combines practical ML with a real decision problem: producing a ranked queue that a content or SEO team can actually use.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# The decision I want to improve is which pages a content or SEO team should review first when their time is limited. The output should be a ranked list rather than just a yes/no prediction. A correct recommendation helps the team focus effort on pages with enough visibility and evidence of decline or opportunity. A wrong recommendation could waste review and editing time on a healthy or low-value page, while a false negative could cause the team to overlook a page that genuinely deserved attention. The model should therefore support human review, not replace it.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

import pandas as pd, numpy as np
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# The label: a page is 'declining' when its recent trend is down. Simple, honest starter label.
df["is_declining_label"] = df["trend_direction"].str.lower().eq("down").astype(int)
print(df.shape[0], "pages |  declining rate:", round(df["is_declining_label"].mean(), 3))

# Match the starter pipeline's basic eligibility rules
eligible = (
    df[(df["impressions_90d"] > 0) & (df["content_age_days"] >= 90)]
    .drop_duplicates("content_id")
)

declining = eligible[eligible["trend_direction"] == "down"]

# Visible declining pages: decline matters more when there is meaningful exposure
visible_declining = declining[declining["impressions_90d"] >= 500]

print(f"Eligible pages: {len(eligible):,}")
print(
    f"Declining pages: {len(declining):,} "
    f"({len(declining) / len(eligible):.1%} of eligible pages)"
)
print(
    f"Declining pages with at least 500 impressions: "
    f"{len(visible_declining):,}"
)
# Out:
# 30000 pages |  declining rate: 0.542
# Eligible pages: 30,000
# Declining pages: 16,262 (54.2% of eligible pages)
# Declining pages with at least 500 impressions: 9,961

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# My project will be able to make observed, directional, and decision-support claims. For example, I can report which measurable signals are associated with decline or opportunity, whether a model ranks useful review candidates better than a transparent baseline, and which pages the model suggests reviewing first. I cannot claim that refreshing a recommended page will cause its traffic to recover, that any feature is a proven Google ranking factor, or that the model predicts Google's algorithm. The final ranking is intended to support human review and prioritization, not guarantee an outcome.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
